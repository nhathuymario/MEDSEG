# %% [markdown]
# # Detection Analysis
# Notebook này để phân tích kết quả dự đoán của Faster R-CNN (BBox, Scores, mAP).

# %%
import torch
from src.models.faster_rcnn import LesionDetector

print('Ready for detection analysis!')
