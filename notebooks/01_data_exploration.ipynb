# %% [markdown]
# # Data Exploration
# Notebook này được sử dụng để khám phá và trực quan hóa các dataset (ISIC 2018 và Chest X-ray).

# %%
import os
import cv2
import matplotlib.pyplot as plt

# Placeholder code for loading and showing sample images
print('Ready for exploration!')
